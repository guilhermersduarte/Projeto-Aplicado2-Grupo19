# %%
import pandas as pd
import numpy as np
from datetime import datetime
import pickle
############
import os
import sys
from packaging import version
import sklearn
import tensorflow as tf

assert sys.version_info >= (3, 7)
assert version.parse(sklearn.__version__) >= version.parse("1.0.1")
assert version.parse(tf.__version__) >= version.parse("2.8.0")
###########

print("TensorFlow version:", tf.__version__)
print("Keras version:", tf.keras.__version__)
print("GPU available:", tf.config.list_physical_devices('GPU'))
#print("MPS backend available:", tf.backends.mps.is_built())
# Out:
# TensorFlow version: 2.20.0
# Keras version: 3.11.3
# GPU available: []

# %% [raw]
# 1. Carregando os dados de importados e tratados do BACEN

# %%
input_data = pd.read_pickle('../dados/df_ata_sentimento.pkl') 
#input_data = pd.read_json('../dados/df_ata_sentimento.json', orient='records', lines=True)
#input_data['Data'] = pd.to_datetime(input_data['Data']).dt.date
#input_data.tail()
# A obtenção de dados da coluna Selic 6m dixa lacunas, limpar os dados:
input_data = input_data.dropna(subset=['Sentimento','Texto'])
input_data = input_data[~(input_data['Texto'].str.strip().isna() | (input_data['Texto'].str.strip() == ''))]
input_data['Texto'] = input_data['Texto'].str.lower()

input_data.sample(5)
# Out:
#           Data                                              Texto  Selic  \
# 216 2023-02-01  a atualização da conjuntura econômica e do cen...  13.75
# 160 2016-01-20  sumário evolução recente da economia avaliação...  14.25
# 125 2011-08-31  sumário evolução recente da economia avaliação...  12.50
# 148 2014-07-16  sumário evolução recente da economia avaliação...  11.00
# 62  2004-07-21  sumário evolução recente da inflação avaliação...  16.00
#
#       IPCA  Selic (6m)  Data (6m) Sentimento
# 216   5.77       13.75 2023-08-02    neutral
# 160  10.71       14.25 2016-07-20    neutral
# 125   7.23       10.50 2012-03-07     dovish
# 148   6.50       11.75 2015-01-21    hawkish
# 62    6.81       16.75 2004-11-17    hawkish

# %% [raw]
# 2. Separando os dados de texto da ata e sentimento para o modelo.

# %%
base_data = input_data[['Texto','Sentimento']]

filename_root = 'gru_sentimento_6m_'
subset_dir = '../../subsets/'
model_dir = '../../'
subset_dir = '../../subsets/'
basepickle = subset_dir + filename_root + '__base.pkl'
base_data.to_pickle(basepickle)
print(base_data.sample(5))
print('Records: ',len(base_data))
# Out:
#                                                  Texto Sentimento
# 7    sumário demanda e oferta agregadas ambiente ex...     dovish
# 34   sumário atividade econômica ambiente externo p...     dovish
# 237  a atualização da conjuntura econômica e do cen...     dovish
# 151  sumário evolução recente da economia avaliação...    hawkish
# 52   sumário evolução recente da inflação avaliação...     dovish
# Records:  206

# %% [raw]
# 3. Preparando os rótulos para processamento. Produzindo dois tipos de rótulos para estudo, um hot encode con três clunad binárias para hdovish, awkish e neutral. Uma quarta coluna com um rótulo de 3 valores, 0,1 e 2
# 0 = dovish
# 1 = hawkisk
# 2 = neutral

# %%
from sklearn.preprocessing import LabelEncoder
#tratamento dos dados para modelo
training_data = base_data.copy()
#Encoding do label alfanumérico
label_encoder = LabelEncoder()
training_data.loc[:, 'sent_encoded'] = label_encoder.fit_transform(training_data['Sentimento'])


# Criando 3 colnuas com hot encoding
one_hot = pd.get_dummies(training_data['Sentimento'], prefix='sent')
training_data = pd.concat([training_data, one_hot], axis=1)

# Renomeando colunas
training_data = training_data.rename(columns={'Texto': 'text'})
training_data = training_data.rename(columns={'Sentimento': 'sent'})

# Display the result
print(training_data.sample(5))
# Out:
#                                                   text     sent  sent_encoded  \
# 200  a atualização da conjuntura econômica e do cen...  hawkish             1
# 230  a atualização da conjuntura econômica e do cen...  hawkish             1
# 8    sumário demanda e oferta agregadas ambiente ex...   dovish             0
# 59   sumário evolução recente da inflação avaliação...   dovish             0
# 19   sumário demanda e oferta agregadas ambiente ex...  hawkish             1
#
#      sent_dovish  sent_hawkish  sent_neutral
# 200        False          True         False
# 230        False          True         False
# 8           True         False         False
# 59          True         False         False
# 19         False          True         False

# %% [raw]
# 4. Variáveis globais - Escopo do modelo e dimensões
# Ainda não geramos um modelo com label con três valores,
# por enquanto modelando cada sentimento sepaeradamente

# %%
# Switch de qual label vai ser estudado.
label_set = 'sent_encoded'
#label_set = 'sent_dovish'
#label_set = 'sent_hawkish'
#label_set = 'sent_neutral'

#Globais de processsamento
batch_size = 32
rnd_seed = 63
num_epochs = 180
num_batches = 32
token_count = 30000
padding_size = 80000
embed_size = 128
train_ratio = 0.4
valid_ratio = 0.1

model_file = model_dir + filename_root + '_GRU_041050_modl_' + label_set + '_' + str(num_epochs) + '_mzt_180_B32.keras'
ckpt_file = model_dir + filename_root + '_GRU_041050_chkp_' + label_set + '_' + str(num_epochs) + '_mzt_220_B32.keras'
print(model_file)
print(ckpt_file)
# Out:
# ../../gru_sentimento_6m__GRU_041050_modl_sent_encoded_180_mzt_180_B32.keras
# ../../gru_sentimento_6m__GRU_041050_chkp_sent_encoded_180_mzt_220_B32.keras

# %%
from sklearn.model_selection import train_test_split

#Migrando dados parsa dataset TensorFlow
df = pd.DataFrame()
df['text'] = training_data['text'].str.lower()
df['label'] = training_data[label_set]  
print(df.head())

# Convert DataFrame to tf.data.Dataset
dataset = tf.data.Dataset.from_tensor_slices((df['text'].values, df['label'].values))

# Optional: Split into train, validation, and test sets (e.g., 80%/10%/10%)
dataset_size = len(df)
train_size = int(train_ratio * dataset_size)
valid_size = int(valid_ratio * dataset_size)
test_size = dataset_size - train_size - valid_size

# Shuffle the dataset (optional, use a seed for reproducibility)
dataset = dataset.shuffle(buffer_size=dataset_size, seed=rnd_seed)

# Split the dataset
raw_train_set = dataset.take(train_size)
raw_valid_set = dataset.skip(train_size).take(valid_size)
raw_test_set = dataset.skip(train_size + valid_size)

print("Train size:", train_size)
print("Valid size:", valid_size)
print("Test size:", test_size)
# Verify the datasets
for text, label in raw_train_set.take(4):
    print("Text:", text.numpy().decode('utf-8')[:100], "Label:", label.numpy())
# Out:
#                                                 text  label
# 0  sumário preços e nível de atividade agregados ...      0
# 1  sumário preços e nível de atividade agregados ...      0
# 2  sumário demanda e oferta agregadas preços agre...      0
# 3  sumário demanda e oferta agregadas ambiente ex...      0
# 4  sumário demanda e oferta agregadas ambiente ex...      2
# Train size: 82
# Valid size: 20
# Test size: 104
# Text: sumário evolução recente da economia avaliação prospectiva das tendências da inflação implementação  Label: 0
# Text: sumário evolução recente da inflação avaliação prospectiva das tendências da inflação implementação  Label: 0
# Text: sumário evolução recente da economia avaliação prospectiva das tendências da inflação implementação  Label: 0
# Text: sumário evolução recente da economia avaliação prospectiva das tendências da inflação implementação  Label: 0
# 2025-11-09 13:14:14.506786: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
#Preparar datasets TensorFlow


tf.random.set_seed(rnd_seed)

train_set = raw_train_set.shuffle(100, seed=rnd_seed).batch(batch_size).prefetch(1)
valid_set = raw_valid_set.batch(batch_size).prefetch(1)
test_set = raw_test_set.batch(batch_size).prefetch(1)

for ata, sentiment in raw_train_set.take(4):
    print(ata.numpy().decode("utf-8")[:200], "...")
    print("Sentiment:", sentiment.numpy())
# Out:
# a atualização da conjuntura econômica e do cenário do copom11 o ambiente externo permanece desafiador em função principalmente da conjuntura e da política econômica nos estados unidos o que suscita ma ...
# Sentiment: 1
# sumário evolução recente da inflação avaliação prospectiva das tendências da inflação implementação da política monetária atividade econômica mercado de trabalho crédito e inadimplência ambiente exter ...
# Sentiment: 2
# sumário atividade econômica ambiente externo preços mercado monetário e operações de mercado aberto avaliação prospectiva das tendências da inflação diretrizes da política monetária glossário data 16  ...
# Sentiment: 1
# sumário evolução recente da economia avaliação prospectiva das tendências da inflação implementação da política monetária inflação atividade econômica expectativas e sondagens mercado de trabalho créd ...
# Sentiment: 0
# 2025-11-09 13:14:14.514083: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
text_vec_layer = tf.keras.layers.TextVectorization(max_tokens=token_count)
text_vec_layer.adapt(train_set.map(lambda texts, labels: texts))

#Possibly save vocabulary for later use
# After text_vec_layer.adapt(...) during training
#vocab = text_vec_layer.get_vocabulary()

# Save vocabulary to file
#import pickle
#with open('text_vectorization_vocab.pkl', 'wb') as f:
#    pickle.dump(vocab, f)

# Optionally save config
#config = text_vec_layer.get_config()
#with open('text_vectorization_config.pkl', 'wb') as f:
#    pickle.dump(config, f)

# %%
#Masking Automatico



tf.random.set_seed(rnd_seed)
model = tf.keras.Sequential([
    text_vec_layer,
    tf.keras.layers.Embedding(token_count, embed_size, mask_zero=True),
    tf.keras.layers.GRU(128),
    #tf.keras.layers.Dense(1, activation="sigmoid")# binário
    tf.keras.layers.Dense(3, activation='softmax')  # 3 classes
])

# Define callback to save the best model based on validation loss
checkpoint_cb = tf.keras.callbacks.ModelCheckpoint(
    ckpt_file,
    monitor="val_loss",
    save_best_only=True,
    save_weights_only=False
)

# If your labels are integers, convert them to one-hot encoded format
# Assuming train_set and valid_set are tf.data.Dataset objects
def convert_to_one_hot(dataset):
    def process_features_labels(features, labels):
        # Convert integer labels to one-hot encoded labels
        labels = tf.one_hot(labels, depth=3)  # depth=3 for 3 classes
        return features, labels
    return dataset.map(process_features_labels)

# Apply one-hot encoding to datasets
train_set_oh = convert_to_one_hot(train_set)
valid_set_oh = convert_to_one_hot(valid_set)

print("Start: ", datetime.now())
#model.compile(loss="binary_crossentropy", optimizer="nadam",
#              metrics=["accuracy"]) # binário
model.compile(loss="categorical_crossentropy", optimizer="nadam",
              metrics=["accuracy"])
180
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 6s/step - accuracy: 0.9878 - loss: 0.0575 - val_accuracy: 1.0000 - val_loss: 0.0309
# Epoch 130/180
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 17s 5s/step - accuracy: 0.9878 - loss: 0.0520 - val_accuracy: 1.0000 - val_loss: 0.0045
# Epoch 131/180
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 16s 5s/step - accuracy: 0.9878 - loss: 0.0414 - val_accuracy: 1.0000 - val_loss: 0.0040
# Epoch 132/180
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 16s 5s/step - accuracy: 1.0000 - loss: 0.0103 - val_accuracy: 0.9500 - val_loss: 0.1522
# Epoch 133/180
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 17s 6s/step - accuracy: 0.9878 - loss: 0.0449 - val_accuracy: 1.0000 - val_loss: 0.0215
# Epoch 134/180
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 6s/step - accuracy: 1.0000 - loss: 0.0056 - val_accuracy: 1.0000 - val_loss: 0.0191
# Epoch 135/180
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 21s 7s/step - accuracy: 1.0000 - loss: 0.0084 - val_accuracy: 1.0000 - val_loss: 0.0089
# Epoch 136/180
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 35s 13s/step - accuracy: 0.9878 - loss: 0.0243 - val_accuracy: 0.9500 - val_loss: 0.1609
# Epoch 137/180
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 117s 38s/step - accuracy: 1.0000 - loss: 0.0116 - val_accuracy: 1.0000 - val_loss: 0.0041
# Epoch 138/180
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 62s 21s/step - accuracy: 0.9878 - loss: 0.0655 - val_accuracy: 1.0000 - val_loss: 0.0072
# Epoch 139/180
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 114s 31s/step - accuracy: 1.0000 - loss: 0.0064 - val_accuracy: 1.0000 - val_loss: 0.0076
# Epoch 140/180
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 78s 32s/step - accuracy: 0.9878 - loss: 0.0394 - val_accuracy: 1.0000 - val_loss: 0.0094
# Epoch 141/180
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 79s 25s/step - accuracy: 1.0000 - loss: 0.0087 - val_accuracy: 1.0000 - val_loss: 0.0097
# Epoch 142/180
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 94s 37s/step - accuracy: 1.0000 - loss: 0.0166 - val_accuracy: 1.0000 - val_loss: 0.0054
# Epoch 143/180
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 83s 20s/step - accuracy: 0.9878 - loss: 0.0287 - val_accuracy: 1.0000 - val_loss: 0.0059
# Epoch 144/180
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 52s 10s/step - accuracy: 1.0000 - loss: 0.0057 - val_accuracy: 1.0000 - val_loss: 0.0035
# Epoch 145/180
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 91s 33s/step - accuracy: 1.0000 - loss: 0.0104 - val_accuracy: 1.0000 - val_loss: 0.0017
# Epoch 146/180
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 105s 42s/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 1.0000 - val_loss: 0.0060
# Epoch 147/180
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 75s 28s/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 1.0000 - val_loss: 6.6375e-04
# Epoch 148/180
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 81s 26s/step - accuracy: 0.9878 - loss: 0.0454 - val_accuracy: 1.0000 - val_loss: 0.0046
# Epoch 149/180
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 75s 27s/step - accuracy: 1.0000 - loss: 0.0120 - val_accuracy: 1.0000 - val_loss: 0.0356
# Epoch 150/180
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 41s 13s/step - accuracy: 0.9878 - loss: 0.0196 - val_accuracy: 1.0000 - val_loss: 0.0017
# Epoch 151/180
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 94s 21s/step - accuracy: 1.0000 - loss: 0.0050 - val_accuracy: 1.0000 - val_loss: 0.0025
# Epoch 152/180
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 103s 27s/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 1.0000 - val_loss: 0.0075
# Epoch 153/180
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 74s 23s/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.9500 - val_loss: 0.1092
# Epoch 154/180
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 67s 22s/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.9500 - val_loss: 0.0926
# Epoch 155/180
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 87s 33s/step - accuracy: 1.0000 - loss: 0.0058 - val_accuracy: 1.0000 - val_loss: 5.8573e-04
# Epoch 156/180
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 111s 33s/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 0.9500 - val_loss: 0.2343
# Epoch 157/180
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 86s 19s/step - accuracy: 1.0000 - loss: 0.0065 - val_accuracy: 1.0000 - val_loss: 9.1047e-04
# Epoch 158/180
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 85s 26s/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 1.0000 - val_loss: 0.0012
# Epoch 159/180
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 84s 27s/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 1.0000 - val_loss: 0.0016
# Epoch 160/180
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 102s 41s/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 1.0000 - val_loss: 0.0019
# Epoch 161/180
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 76s 24s/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 1.0000 - val_loss: 8.4781e-04
# Epoch 162/180
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 97s 37s/step - accuracy: 0.9878 - loss: 0.0109 - val_accuracy: 1.0000 - val_loss: 0.0041
# Epoch 163/180
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 65s 25s/step - accuracy: 1.0000 - loss: 0.0047 - val_accuracy: 1.0000 - val_loss: 0.0084
# Epoch 164/180
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 59s 24s/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 1.0000 - val_loss: 0.0016
# Epoch 165/180
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 98s 37s/step - accuracy: 1.0000 - loss: 0.0060 - val_accuracy: 1.0000 - val_loss: 0.0261
# Epoch 166/180
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 69s 25s/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 1.0000 - val_loss: 7.4741e-04
# Epoch 167/180
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 88s 35s/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 1.0000 - val_loss: 7.2158e-04
# Epoch 168/180
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 108s 41s/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 1.0000 - val_loss: 0.0019
# Epoch 169/180
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 41s 14s/step - accuracy: 0.9878 - loss: 0.0105 - val_accuracy: 1.0000 - val_loss: 6.2644e-04
# Epoch 170/180
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 70s 18s/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 1.0000 - val_loss: 0.0028
# Epoch 171/180
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 58s 18s/step - accuracy: 0.9878 - loss: 0.0772 - val_accuracy: 1.0000 - val_loss: 0.0296
# Epoch 172/180
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 82s 29s/step - accuracy: 0.9878 - loss: 0.0396 - val_accuracy: 1.0000 - val_loss: 0.0045
# Epoch 173/180
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 91s 35s/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 1.0000 - val_loss: 0.0077
# Epoch 174/180
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 73s 18s/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 1.0000 - val_loss: 0.0028
# Epoch 175/180
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 83s 26s/step - accuracy: 1.0000 - loss: 0.0050 - val_accuracy: 0.9500 - val_loss: 0.1099
# Epoch 176/180
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 67s 17s/step - accuracy: 0.9756 - loss: 0.0445 - val_accuracy: 1.0000 - val_loss: 0.0020
# Epoch 177/180
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 25s 9s/step - accuracy: 0.9756 - loss: 0.0647 - val_accuracy: 1.0000 - val_loss: 0.0046
# Epoch 178/180
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 22s 6s/step - accuracy: 0.9634 - loss: 0.0566 - val_accuracy: 1.0000 - val_loss: 0.0053
# Epoch 179/180
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 24s 10s/step - accuracy: 1.0000 - loss: 0.0075 - val_accuracy: 1.0000 - val_loss: 0.0241
# Epoch 180/180
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 21s 7s/step - accuracy: 1.0000 - loss: 0.0108 - val_accuracy: 1.0000 - val_loss: 0.0042
# End:  2025-11-09 16:07:38.875734

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
#Salvando datasets
test_set_dir = subset_dir + filename_root + f"tr_ {train_ratio:.2f}" + "_test_set"
os.makedirs(test_set_dir, exist_ok=True)
tf.data.Dataset.save(test_set, test_set_dir)
print(test_set_dir)

train_set_dir = subset_dir + filename_root + f"tr_ {train_ratio:.2f}" + "_train_set"
os.makedirs(train_set_dir, exist_ok=True)
tf.data.Dataset.save(train_set, test_set_dir)
print(train_set_dir)

valid_set_dir = subset_dir + filename_root + f"tr_ {train_ratio:.2f}" + "_valid_set"
os.makedirs(valid_set_dir, exist_ok=True)
tf.data.Dataset.save(valid_set, valid_set_dir)
print(valid_set_dir)
# Out:
# ../../subsets/gru_sentimento_6m_tr_ 0.40_test_set
# ../../subsets/gru_sentimento_6m_tr_ 0.40_train_set
# ../../subsets/gru_sentimento_6m_tr_ 0.40_valid_set

# %%
import keras
import os
print(model_file)
keras.saving.save_model(model, model_file)
orgname, ext = name, ext = os.path.splitext(model_file)
vl_model_file = orgname + '_VECLYR_' + ext
model.save(vl_model_file, save_format='tf')
print(vl_model_file)
# Out:
# WARNING:absl:The `save_format` argument is deprecated in Keras 3. We recommend removing this argument as it can be inferred from the file path. Received: save_format=tf
# ../../gru_sentimento_6m__GRU_041050_modl_sent_encoded_180_mzt_180_B32.keras
# ../../gru_sentimento_6m__GRU_041050_modl_sent_encoded_180_mzt_180_B32_VECLYR_.keras

# %%
vocab_file = orgname + '_texveclayer_VOCAB.pkl'
config_file = orgname + '_texveclayer_CONFIG.pkl'
print(vocab_file)
print(config_file)

# Save vocabulary to file

vocab = text_vec_layer.get_vocabulary()
with open(vocab_file, 'wb') as f:
    pickle.dump(vocab, f)

# Optionally save config
config = text_vec_layer.get_config()
with open(config_file, 'wb') as f:
    pickle.dump(config, f)
# Out:
# ../../gru_sentimento_6m__GRU_041050_modl_sent_encoded_180_mzt_180_B32_texveclayer_VOCAB.pkl
# ../../gru_sentimento_6m__GRU_041050_modl_sent_encoded_180_mzt_180_B32_texveclayer_CONFIG.pkl

# %%
test_set_oh = convert_to_one_hot(test_set)
test_loss, test_accuracy = model.evaluate(test_set_oh)
print(f"Test Accuracy: {test_accuracy:.4f}")
print(f"Test Loss: {test_loss:.4f}")
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 784ms/step - accuracy: 1.0000 - loss: 0.0190
# Test Accuracy: 1.0000
# Test Loss: 0.0190

# %%
# Step 1: Extract true labels and predictions
y_true = []
y_pred = []

for x_batch, y_batch in test_set_oh:
    # Get true labels (one-hot encoded) and convert to class indices
    y_true_batch = tf.argmax(y_batch, axis=1).numpy()  # Convert one-hot to indices
    y_true.extend(y_true_batch)
    
    # Get model predictions and convert to class indices
    y_pred_prob = model.predict(x_batch, verbose=0)  # Predict probabilities
    y_pred_batch = tf.argmax(y_pred_prob, axis=1).numpy()  # Convert to indices
    y_pred.extend(y_pred_batch)

# Convert lists to numpy arrays
y_true = np.array(y_true)
y_pred = np.array(y_pred)
# Out:
# 2025-11-09 16:07:46.053246: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
#0 = dovish
#1 = hawkisk
#2 = neutral

from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
# Step 2: Generate confusion matrix
cm = confusion_matrix(y_true, y_pred)

# Step 3: Visualize the confusion matrix (optional)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Grays', 
            xticklabels=['dovish', 'hawkisk', 'neutral'], 
            yticklabels=['dovish', 'hawkisk', 'neutral'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# Print the confusion matrix
print("Confusion Matrix:\n", cm)
from sklearn.metrics import classification_report
# Define the labels
labels = ['dovish', 'hawkisk', 'neutral']

# Generate classification report
report = classification_report(y_true, y_pred, target_names=labels)

# Print the classification report
print("Classification Report:")
print(report)
# Out:
# Confusion Matrix:
#  [[50  0  0]
#  [ 0 41  0]
#  [ 0  0 13]]
# Classification Report:
#               precision    recall  f1-score   support
#
#       dovish       1.00      1.00      1.00        50
#      hawkisk       1.00      1.00      1.00        41
#      neutral       1.00      1.00      1.00        13
#
#     accuracy                           1.00       104
#    macro avg       1.00      1.00      1.00       104
# weighted avg       1.00      1.00      1.00       104

# %%
input_pred_data = pd.read_pickle('../dados/df_ata_sentimento_predict.pkl') 
#input_pred_data = pd.read_json('../dados/df_ata_sentimento.json', orient='records', lines=True)
#input_pred_data['Data'] = pd.to_datetime(input_data['Data']).dt.date
input_pred_data['Texto'] = input_pred_data['Texto'].str.lower()

predict_data = input_pred_data[['Texto', 'Data','Selic']]

print(predict_data)
print('Records: ',len(predict_data))
# Out:
#                                                  Texto       Data  Selic
# 234  a atualização da conjuntura econômica e do cen... 2025-05-07  14.25
# 235  a atualização da conjuntura econômica e do cen... 2025-06-18  14.75
# 236  a atualização da conjuntura econômica e do cen... 2025-07-30  15.00
# 237  a atualização da conjuntura econômica e do cen... 2025-09-17  15.00
# Records:  4

# %%
predict_data = predict_data.rename(columns={'Texto': 'text'})
predict_data = predict_data.rename(columns={'Data': 'date'})
predict_data = predict_data.rename(columns={'Selic': 'rate'})
predict_data['next_date']= ['2025-11-05', '2025-12-10', '2026-01-28', '2026-03-18']
predict_data['sentiment'] = None
predict_data['next_date']
# Próxinmas 2025-11-05, 2025-12-10, 2026-01-28, 2026-03-18
print(predict_data)

this_text = predict_data.iloc[3,0]
this_text_list =  predict_data['text'].astype(str).values.tolist()
# Out:
#                                                   text       date   rate  \
# 234  a atualização da conjuntura econômica e do cen... 2025-05-07  14.25
# 235  a atualização da conjuntura econômica e do cen... 2025-06-18  14.75
# 236  a atualização da conjuntura econômica e do cen... 2025-07-30  15.00
# 237  a atualização da conjuntura econômica e do cen... 2025-09-17  15.00
#
#       next_date sentiment
# 234  2025-11-05      None
# 235  2025-12-10      None
# 236  2026-01-28      None
# 237  2026-03-18      None

# %%
def predict_text(raw_texts, model):
    # Step 1: Ensure raw_texts is a NumPy array of strings
    if isinstance(raw_texts, str):
        raw_texts = [raw_texts]  # Wrap single string in a list
    raw_texts = np.array(raw_texts, dtype=str)  # Convert to NumPy array of strings
    
    # Step 2: Convert to TensorFlow tensor with shape (batch_size,)
    input_tensor = tf.convert_to_tensor(raw_texts, dtype=tf.string)
    
    # Step 3: Make predictions
    predictions = model.predict(input_tensor,verbose=0)
    
    # Step 4: Interpret the predictions
    predicted_classes = np.argmax(predictions, axis=1)
    probabilities = predictions
    
    return predicted_classes, probabilities

# %%
#0 = dovish
#1 = hawkisk
#2 = neutral

for index,row in predict_data.iterrows():
    
    predict_data.at[index, 'sentiment'] = 'to calculate'
    
    new_text = [row['text']]
    predicted_classes, probabilities = predict_text(new_text, model)
    my_class = predicted_classes[0]
    if my_class == 0:
        predict_data.at[index, 'sentiment'] = 'dovish'
    elif my_class == 1:
        predict_data.at[index, 'sentiment'] = 'hawkish'
    else:
        predict_data.at[index, 'sentiment'] = 'neutral'

predict_data
# Out:
#                                                   text       date   rate  \
# 234  a atualização da conjuntura econômica e do cen... 2025-05-07  14.25
# 235  a atualização da conjuntura econômica e do cen... 2025-06-18  14.75
# 236  a atualização da conjuntura econômica e do cen... 2025-07-30  15.00
# 237  a atualização da conjuntura econômica e do cen... 2025-09-17  15.00
#
#       next_date sentiment
# 234  2025-11-05    dovish
# 235  2025-12-10    dovish
# 236  2026-01-28    dovish
# 237  2026-03-18    dovish
